# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1,"None", 3, 4],
    'B': [5, 6, 7, 8],
    'C': [9, 10, 11, 12],
    'D': [13, 14, 15, 16],
    })

df
# Out:
#    A  B   C   D
# 0  1  5   9  13
# 1  2  6  10  14
# 2  3  7  11  15
# 3  4  8  12  16
